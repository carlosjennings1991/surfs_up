# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
Measurement.classes.keys()
# Out:
# ['measurement', 'station']

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 1a: (Carlos created): Create a variable that only hold June time-data.
dates = session.query(Measurement.date)
date_list = dates.all()
#june_2010 = date_list[133:162] # this is for 2010 june
#june_2011 = date_list[470:496] # this is for 2011 june
#june_2012 = date_list[823:853]


only_june = []
for date in date_list:
    i = 0
    #if date[i][4:8] == '-06-':
    if '-06-' in date[i]:
        #print(date[i])
        only_june.append(date[i])
    i += 1

#only_june = only_june[0:236]
len(only_june)
# Out:
# 1700

# %%
only_dec = []
for date in date_list:
    i = 0
    #if date[i][4:8] == '-12-':
    if '-12-' in date[i]:
        #print(date[i])
        only_dec.append(date[i])
    i += 1
    
len(only_dec)
# Out:
# 1517

# %%
only_dec[0:210]
# Out:
# ['2010-12-01',
#  '2010-12-03',
#  '2010-12-04',
#  '2010-12-06',
#  '2010-12-07',
#  '2010-12-08',
#  '2010-12-09',
#  '2010-12-10',
#  '2010-12-11',
#  '2010-12-12',
#  '2010-12-13',
#  '2010-12-14',
#  '2010-12-15',
#  '2010-12-16',
#  '2010-12-17',
#  '2010-12-18',
#  '2010-12-19',
#  '2010-12-23',
#  '2010-12-24',
#  '2010-12-26',
#  '2010-12-27',
#  '2010-12-28',
#  '2010-12-29',
#  '2010-12-30',
#  '2010-12-31',
#  '2011-12-01',
#  '2011-12-02',
#  '2011-12-03',
#  '2011-12-04',
#  '2011-12-05',
#  '2011-12-06',
#  '2011-12-07',
#  '2011-12-08',
#  '2011-12-09',
#  '2011-12-10',
#  '2011-12-11',
#  '2011-12-12',
#  '2011-12-13',
#  '2011-12-14',
#  '2011-12-15',
#  '2011-12-16',
#  '2011-12-17',
#  '2011-12-18',
#  '2011-12-19',
#  '2011-12-20',
#  '2011-12-21',
#  '2011-12-22',
#  '2011-12-23',
#  '2011-12-24',
#  '2011-12-25',
#  '2011-12-26',
#  '2011-12-27',
#  '2011-12-28',
#  '2011-12-29',
#  '2011-12-30',
#  '2011-12-31',
#  '2012-12-01',
#  '2012-12-02',
# ...

# %%
# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June.
june_temps = session.query(Measurement).filter(extract('month', Measurement.date)==6)

# %%
#  3. Convert the June temperatures to a list.
june_temps_list = [day_temp.tobs for day_temp in june_temps]

#june_temps_list = june_temps_list[0:236]

june_temps_list
# Out:
# [78.0,
#  76.0,
#  78.0,
#  76.0,
#  77.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  77.0,
#  82.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  73.0,
#  70.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  76.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  77.0,
#  77.0,
#  76.0,
#  78.0,
#  77.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  73.0,
#  73.0,
#  75.0,
#  77.0,
#  76.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  73.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  74.0,
# ...

# %%
import pandas as pd
# 4. Create a DataFrame from the list of temperatures for the month of June. 
june_df = pd.DataFrame(june_temps_list)

june_df
# Out:
#          0
# 0     78.0
# 1     76.0
# 2     78.0
# 3     76.0
# 4     77.0
# ...    ...
# 1695  79.0
# 1696  74.0
# 1697  74.0
# 1698  76.0
# 1699  75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_df.describe()
# Out:
#                  0
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_temps = session.query(Measurement).filter(extract('month', Measurement.date)==12)

# %%
# 7. Convert the December temperatures to a list.
dec_temps_list = [day_temp.tobs for day_temp in dec_temps]

#dec_temps_list = dec_temps_list[0:210]

dec_temps_list
# Out:
# [76.0,
#  74.0,
#  74.0,
#  64.0,
#  64.0,
#  67.0,
#  77.0,
#  66.0,
#  69.0,
#  68.0,
#  68.0,
#  71.0,
#  74.0,
#  67.0,
#  66.0,
#  69.0,
#  71.0,
#  70.0,
#  70.0,
#  74.0,
#  74.0,
#  71.0,
#  75.0,
#  75.0,
#  72.0,
#  69.0,
#  68.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  73.0,
#  71.0,
#  73.0,
#  73.0,
#  77.0,
#  72.0,
#  71.0,
#  73.0,
#  70.0,
#  73.0,
#  69.0,
#  74.0,
#  72.0,
#  71.0,
#  72.0,
#  72.0,
#  70.0,
#  73.0,
#  73.0,
#  72.0,
#  73.0,
#  73.0,
#  72.0,
#  63.0,
#  65.0,
#  71.0,
#  76.0,
#  70.0,
#  76.0,
#  69.0,
#  69.0,
#  69.0,
#  74.0,
#  76.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  74.0,
#  74.0,
#  71.0,
#  73.0,
#  72.0,
#  64.0,
#  66.0,
#  73.0,
#  72.0,
#  65.0,
#  64.0,
#  69.0,
#  68.0,
#  77.0,
#  71.0,
#  71.0,
#  69.0,
#  68.0,
#  68.0,
#  69.0,
#  70.0,
#  72.0,
#  76.0,
#  75.0,
#  69.0,
#  71.0,
#  71.0,
#  71.0,
#  68.0,
#  65.0,
#  70.0,
#  69.0,
#  69.0,
#  71.0,
#  67.0,
#  73.0,
#  74.0,
#  73.0,
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_df = pd.DataFrame(dec_temps_list)
dec_df
# Out:
#          0
# 0     76.0
# 1     74.0
# 2     74.0
# 3     64.0
# 4     64.0
# ...    ...
# 1512  71.0
# 1513  71.0
# 1514  69.0
# 1515  65.0
# 1516  65.0
#
# [1517 rows x 1 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_df.describe()
# Out:
#                  0
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %% [markdown]
# # This is for my own testing, please igonore if you are grading the assignment:

# %%
# below is how you would do a compound extract

x = session.query(Measurement).filter(extract('month', Measurement.date)==2, extract('day', Measurement.date)==29)

x

# %%
# How do you know to use 'tobs?'

x_list = [y.tobs for y in x]

x_list
# Out:
# [74.0,
#  71.0,
#  72.0,
#  79.0,
#  70.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  67.0,
#  70.0,
#  69.0,
#  74.0,
#  69.0,
#  68.0]

# %%
len(x_list)
# Out:
# 15

# %%
# get all the attributes for the Measurement object

Measurement.__dict__
# Out:
# mappingproxy({'__table__': Table('measurement', MetaData(bind=None), Column('id', INTEGER(), table=<measurement>, primary_key=True, nullable=False), Column('station', TEXT(), table=<measurement>), Column('date', TEXT(), table=<measurement>), Column('prcp', FLOAT(), table=<measurement>), Column('tobs', FLOAT(), table=<measurement>), schema=None),
#               '__module__': 'sqlalchemy.ext.automap',
#               '__doc__': None,
#               '_sa_class_manager': <ClassManager of <class 'sqlalchemy.ext.automap.measurement'> at 7f99bb0d0ad0>,
#               '__init__': <function __init__(self, **kwargs)>,
#               'id': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb156650>,
#               'station': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb1566b0>,
#               'date': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb156830>,
#               'prcp': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb156770>,
# ...

# %%
session.query(Measurement.tobs).all()
# Out:
# [(65.0),
#  (63.0),
#  (74.0),
#  (76.0),
#  (73.0),
#  (70.0),
#  (64.0),
#  (68.0),
#  (73.0),
#  (64.0),
#  (61.0),
#  (66.0),
#  (65.0),
#  (68.0),
#  (64.0),
#  (72.0),
#  (66.0),
#  (66.0),
#  (69.0),
#  (67.0),
#  (67.0),
#  (71.0),
#  (67.0),
#  (76.0),
#  (68.0),
#  (72.0),
#  (70.0),
#  (67.0),
#  (66.0),
#  (67.0),
#  (69.0),
#  (67.0),
#  (67.0),
#  (64.0),
#  (69.0),
#  (73.0),
#  (73.0),
#  (69.0),
#  (69.0),
#  (69.0),
#  (71.0),
#  (61.0),
#  (69.0),
#  (63.0),
#  (64.0),
#  (65.0),
#  (67.0),
#  (68.0),
#  (65.0),
#  (76.0),
#  (75.0),
#  (66.0),
#  (70.0),
#  (72.0),
#  (73.0),
#  (70.0),
#  (71.0),
#  (72.0),
#  (72.0),
#  (69.0),
#  (70.0),
#  (73.0),
#  (72.0),
#  (73.0),
#  (70.0),
#  (71.0),
#  (68.0),
#  (70.0),
#  (72.0),
#  (69.0),
#  (68.0),
#  (74.0),
#  (72.0),
#  (72.0),
#  (73.0),
#  (74.0),
#  (73.0),
#  (73.0),
#  (74.0),
#  (74.0),
#  (74.0),
#  (71.0),
#  (72.0),
#  (75.0),
#  (75.0),
#  (75.0),
#  (75.0),
#  (73.0),
#  (73.0),
#  (71.0),
# ...

# %%
# get all the attributes for the Station object

Station.__dict__
# Out:
# mappingproxy({'__table__': Table('station', MetaData(bind=None), Column('id', INTEGER(), table=<station>, primary_key=True, nullable=False), Column('station', TEXT(), table=<station>), Column('name', TEXT(), table=<station>), Column('latitude', FLOAT(), table=<station>), Column('longitude', FLOAT(), table=<station>), Column('elevation', FLOAT(), table=<station>), schema=None),
#               '__module__': 'sqlalchemy.ext.automap',
#               '__doc__': None,
#               '_sa_class_manager': <ClassManager of <class 'sqlalchemy.ext.automap.station'> at 7f99bb0a8770>,
#               '__init__': <function __init__(self, **kwargs)>,
#               'id': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb0e3350>,
#               'station': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb0e36b0>,
#               'name': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x7f99bb0e33b0>,
# ...

# %%
# Figure out whatever the fuck this thing is. 

Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
type(Base.classes)
# Out:
# sqlalchemy.util._collections.Properties
